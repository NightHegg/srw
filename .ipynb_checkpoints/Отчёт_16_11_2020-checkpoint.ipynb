# %%
import numpy as np
from programDisplacements import mainProgram as mp
import matplotlib.pyplot as plt

# %%
nameFile = "test_1.dat"
u, Eps, Sigma, graph = mp(nameFile)
graph(u)
# Out:
# Sigma_xx (-1.0303e+07 -1.0303e+07)
# Sigma_yy (-2e+07 -2e+07)
# Sigma_xy (-0.000206773 0.0003283)
